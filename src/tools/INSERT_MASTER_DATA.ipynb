# %%
# %sql
-- 1. 不整合が起きている古いテーブルを完全に消去する
DROP TABLE IF EXISTS cf_mom_factory_dev_matsuot.master.m_factory;

-- 2. テーブルを新しく再作成する
CREATE TABLE cf_mom_factory_dev_matsuot.master.m_factory (
    factory_id STRING NOT NULL,
    factory_name STRING,
    location_name STRING,
    _input_file_path STRING,
    _processed_timestamp TIMESTAMP
)
USING delta;

-- 3. 主キー制約を付け直す
ALTER TABLE cf_mom_factory_dev_matsuot.master.m_factory 
ADD CONSTRAINT m_factory_pk PRIMARY KEY (factory_id);

-- 4. 増量データを一気に挿入する
INSERT INTO cf_mom_factory_dev_matsuot.master.m_factory (
    factory_id, 
    factory_name, 
    location_name, 
    _input_file_path, 
    _processed_timestamp
) 
VALUES 
    ('F01', '本社第一工場', '愛知県豊田市', 's3://cf-mom-factory-secrets-dev/master_source/m_factory.csv', CURRENT_TIMESTAMP()),
    ('F02', '九州第二工場', '福岡県宮若市', 's3://cf-mom-factory-secrets-dev/master_source/m_factory.csv', CURRENT_TIMESTAMP()),
    ('F03', '東北第三工場', '岩手県金ケ崎町', 's3://cf-mom-factory-secrets-dev/master_source/m_factory.csv', CURRENT_TIMESTAMP()),
    ('F04', '鈴鹿第四工場', '三重県鈴鹿市', 's3://cf-mom-factory-secrets-dev/master_source/m_factory.csv', CURRENT_TIMESTAMP()),
    ('F05', '追浜第五工場', '神奈川県横須賀市', 's3://cf-mom-factory-secrets-dev/master_source/m_factory.csv', CURRENT_TIMESTAMP()),
    ('F06', '栃木第六工場', '栃木県上三川町', 's3://cf-mom-factory-secrets-dev/master_source/m_factory.csv', CURRENT_TIMESTAMP()),
    ('F07', '群馬第七工場', '群馬県太田市', 's3://cf-mom-factory-secrets-dev/master_source/m_factory.csv', CURRENT_TIMESTAMP()),
    ('F08', '寄居第八工場', '埼玉県寄居町', 's3://cf-mom-factory-secrets-dev/master_source/m_factory.csv', CURRENT_TIMESTAMP()),
    ('F09', '水島第九工場', '岡山県倉敷市', 's3://cf-mom-factory-secrets-dev/master_source/m_factory.csv', CURRENT_TIMESTAMP()),
    ('F10', '滋賀第十工場', '滋賀県竜王町', 's3://cf-mom-factory-secrets-dev/master_source/m_factory.csv', CURRENT_TIMESTAMP()),
    ('F11', '池田第十一工場', '大阪府池田市', 's3://cf-mom-factory-secrets-dev/master_source/m_factory.csv', CURRENT_TIMESTAMP()),
    ('F12', '苫小牧第十二工場', '北海道苫小牧市', 's3://cf-mom-factory-secrets-dev/master_source/m_factory.csv', CURRENT_TIMESTAMP());

# %%
# %sql
-- 古いテーブルがある場合は一度完全に削除（S3不整合対策）
DROP TABLE IF EXISTS cf_mom_factory_dev_matsuot.master.m_process;

-- テーブルの再作成
CREATE TABLE cf_mom_factory_dev_matsuot.master.m_process (
    process_code STRING NOT NULL,
    process_name STRING,
    process_disp_name STRING,
    sort_order INT,
    _input_file_path STRING,
    _processed_timestamp TIMESTAMP
)
USING delta;

-- 主キー制約の追加
ALTER TABLE cf_mom_factory_dev_matsuot.master.m_process 
ADD CONSTRAINT m_process_pk PRIMARY KEY (process_code);

-- 12工程にボリュームを増やしてデータを挿入
INSERT INTO cf_mom_factory_dev_matsuot.master.m_process (
    process_code, 
    process_name, 
    process_disp_name, 
    sort_order, 
    _input_file_path, 
    _processed_timestamp
) 
VALUES 
    ('P01', 'Stamping',             'プレス工程',       1,  's3://cf-mom-factory-secrets-dev/master_source/m_process.csv', CURRENT_TIMESTAMP()),
    ('P02', 'Welding',              '溶接工程',         2,  's3://cf-mom-factory-secrets-dev/master_source/m_process.csv', CURRENT_TIMESTAMP()),
    ('P03', 'Painting',             '塗装工程',         3,  's3://cf-mom-factory-secrets-dev/master_source/m_process.csv', CURRENT_TIMESTAMP()),
    ('P04', 'Assembly',             '組立工程',         4,  's3://cf-mom-factory-secrets-dev/master_source/m_process.csv', CURRENT_TIMESTAMP()),
    ('P05', 'Inspection',           '検査工程',         5,  's3://cf-mom-factory-secrets-dev/master_source/m_process.csv', CURRENT_TIMESTAMP()),
    ('P06', 'Powertrain_Assembly',  'パワートレイン組立', 6,  's3://cf-mom-factory-secrets-dev/master_source/m_process.csv', CURRENT_TIMESTAMP()),
    ('P07', 'Battery_Mounting',     '電池パック搭載',   7,  's3://cf-mom-factory-secrets-dev/master_source/m_process.csv', CURRENT_TIMESTAMP()),
    ('P08', 'Chassis_Marriage',     'シャシードッキング', 8,  's3://cf-mom-factory-secrets-dev/master_source/m_process.csv', CURRENT_TIMESTAMP()),
    ('P09', 'Interior_Fitting',     '内装品組付工程',   9,  's3://cf-mom-factory-secrets-dev/master_source/m_process.csv', CURRENT_TIMESTAMP()),
    ('P10', 'Final_Adjustment',     '最終調整工程',     10, 's3://cf-mom-factory-secrets-dev/master_source/m_process.csv', CURRENT_TIMESTAMP()),
    ('P11', 'Quality_Audit',        '品質監査工程',     11, 's3://cf-mom-factory-secrets-dev/master_source/m_process.csv', CURRENT_TIMESTAMP()),
    ('P12', 'Shipping_Preparation', '出荷準備・防錆',   12, 's3://cf-mom-factory-secrets-dev/master_source/m_process.csv', CURRENT_TIMESTAMP());

# %%
# %sql
DROP TABLE IF EXISTS cf_mom_factory_dev_matsuot.master.m_car_model;

CREATE TABLE cf_mom_factory_dev_matsuot.master.m_car_model (
    car_model_code STRING NOT NULL,
    car_model_name STRING,
    powertrain_type STRING,
    segment_code STRING,
    _input_file_path STRING,
    _processed_timestamp TIMESTAMP
)
USING delta;

ALTER TABLE cf_mom_factory_dev_matsuot.master.m_car_model 
ADD CONSTRAINT m_car_model_pk PRIMARY KEY (car_model_code);

INSERT INTO cf_mom_factory_dev_matsuot.master.m_car_model (
    car_model_code,
    car_model_name,
    powertrain_type,
    segment_code,
    _input_file_path,
    _processed_timestamp
)
VALUES 
    ('PRIUS-HEV',  'プリウス',           'HEV',      'Medium',   's3://cf-mom-factory-secrets-dev/master_source/m_car_model.csv', CURRENT_TIMESTAMP()),
    ('YARIS-GAS',  'ヤリス',             'Gasoline', 'Compact',  's3://cf-mom-factory-secrets-dev/master_source/m_car_model.csv', CURRENT_TIMESTAMP()),
    ('YARISC-HEV', 'ヤリスクロスHEV',         'HEV',      'Compact',  's3://cf-mom-factory-secrets-dev/master_source/m_car_model.csv', CURRENT_TIMESTAMP()),
    ('BZ4X-EV',    'bZ4X',              'EV',       'SUV',      's3://cf-mom-factory-secrets-dev/master_source/m_car_model.csv', CURRENT_TIMESTAMP()),
    ('RAV4-PHEV',  'RAV4',              'PHEV',     'SUV',      's3://cf-mom-factory-secrets-dev/master_source/m_car_model.csv', CURRENT_TIMESTAMP()),
    ('HIACE-DSL',  'ハイエース',         'Diesel',   'Van',      's3://cf-mom-factory-secrets-dev/master_source/m_car_model.csv', CURRENT_TIMESTAMP()),
    ('CROWN-HEV',  'クラウンクロスオーバー', 'HEV',      'Luxury',   's3://cf-mom-factory-secrets-dev/master_source/m_car_model.csv', CURRENT_TIMESTAMP()),
    ('ALPH-HEV',   'アルファード',       'HEV',      'Minivan',  's3://cf-mom-factory-secrets-dev/master_source/m_car_model.csv', CURRENT_TIMESTAMP()),
    ('SIENTA-GAS', 'シエンタ',           'Gasoline', 'Compact',  's3://cf-mom-factory-secrets-dev/master_source/m_car_model.csv', CURRENT_TIMESTAMP());

# %%
# %sql
DROP TABLE IF EXISTS cf_mom_factory_dev_matsuot.master.m_operator_resource;

CREATE TABLE cf_mom_factory_dev_matsuot.master.m_operator_resource (
    operator_id STRING NOT NULL,
    resource_type STRING,
    resource_name STRING,
    department_or_vendor STRING,
    _input_file_path STRING,
    _processed_timestamp TIMESTAMP
)
USING delta;

ALTER TABLE cf_mom_factory_dev_matsuot.master.m_operator_resource 
ADD CONSTRAINT m_operator_resource_pk PRIMARY KEY (operator_id);

INSERT INTO cf_mom_factory_dev_matsuot.master.m_operator_resource (
    operator_id,
    resource_type,
    resource_name,
    department_or_vendor,
    _input_file_path,
    _processed_timestamp
)
VALUES 
    ('OP-101', '1', '山田 太郎', 'プレス第一課', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-102', '1', '佐藤 次郎', '溶接管理課', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-103', '1', '高橋 新一', '塗装技術課', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-104', '1', '鈴木 三郎', '組立第一課', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-105', '1', '田中 一郎', '組立第二課', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-106', '1', '渡辺 健二', '品質検査課', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-107', '1', '伊藤 芳雄', '品質検査課', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-201', '2', 'ROBOT-STMP-01', 'Komatsu', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-202', '2', 'ROBOT-WELD-01', 'Fanuc', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-203', '2', 'ROBOT-WELD-02', 'Fanuc', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-204', '2', 'ROBOT-PNT-01', 'Yaskawa', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-205', '2', 'ROBOT-PNT-02', 'Yaskawa', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-206', '2', 'ROBOT-ASY-01', 'KUKA', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-207', '2', 'ROBOT-ASY-02', 'ABB', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP()),
    ('OP-208', '2', 'ROBOT-INSP-01', 'Keyence', 's3://cf-mom-factory-secrets-dev/master_source/m_operator_resource.csv', CURRENT_TIMESTAMP());

# %%
# %sql
CREATE TABLE cf_engineering_dev_matsuot.master.m_sp_production_standard (
    car_model_code STRING NOT NULL,
    process_code STRING NOT NULL,
    design_version STRING NOT NULL,
    bom_id STRING,
    target_cycle_time DOUBLE,
    _input_file_path STRING,
    _processed_timestamp TIMESTAMP
)
USING delta;

ALTER TABLE cf_engineering_dev_matsuot.master.m_sp_production_standard 
ADD CONSTRAINT m_sp_production_standard_pk PRIMARY KEY (car_model_code, process_code, design_version);

# %%
# %sql
DROP TABLE IF EXISTS cf_engineering_dev_matsuot.master.m_production_standard;

CREATE TABLE cf_engineering_dev_matsuot.master.m_production_standard (
    car_model_code STRING NOT NULL,
    process_code STRING NOT NULL,
    design_version STRING NOT NULL,
    bom_id STRING,
    target_cycle_time DOUBLE,
    _input_file_path STRING,
    _processed_timestamp TIMESTAMP
)
USING delta;

ALTER TABLE cf_engineering_dev_matsuot.master.m_production_standard 
ADD CONSTRAINT m_production_standard_pk PRIMARY KEY (car_model_code, process_code, design_version);

INSERT INTO cf_engineering_dev_matsuot.master.m_production_standard (
    car_model_code,
    process_code,
    design_version,
    bom_id,
    target_cycle_time,
    _input_file_path,
    _processed_timestamp
)
VALUES 
    -- PRIUS-HEV (全12工程)
    ('PRIUS-HEV', 'P01', 'REV-1.00', 'BOM-PRIUS-001', 35.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('PRIUS-HEV', 'P02', 'REV-1.00', 'BOM-PRIUS-001', 50.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('PRIUS-HEV', 'P03', 'REV-1.00', 'BOM-PRIUS-001', 85.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('PRIUS-HEV', 'P04', 'REV-1.00', 'BOM-PRIUS-001', 110.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('PRIUS-HEV', 'P05', 'REV-1.00', 'BOM-PRIUS-001', 55.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('PRIUS-HEV', 'P06', 'REV-1.00', 'BOM-PRIUS-001', 70.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('PRIUS-HEV', 'P07', 'REV-1.00', 'BOM-PRIUS-001', 40.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('PRIUS-HEV', 'P08', 'REV-1.00', 'BOM-PRIUS-001', 65.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('PRIUS-HEV', 'P09', 'REV-1.00', 'BOM-PRIUS-001', 95.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('PRIUS-HEV', 'P10', 'REV-1.00', 'BOM-PRIUS-001', 50.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('PRIUS-HEV', 'P11', 'REV-1.00', 'BOM-PRIUS-001', 60.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('PRIUS-HEV', 'P12', 'REV-1.00', 'BOM-PRIUS-001', 30.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),

    -- YARIS-GAS (全12工程)
    ('YARIS-GAS', 'P01', 'REV-2.00', 'BOM-YARIS-102', 30.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARIS-GAS', 'P02', 'REV-2.00', 'BOM-YARIS-102', 45.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARIS-GAS', 'P03', 'REV-2.00', 'BOM-YARIS-102', 80.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARIS-GAS', 'P04', 'REV-2.00', 'BOM-YARIS-102', 105.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARIS-GAS', 'P05', 'REV-2.00', 'BOM-YARIS-102', 50.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARIS-GAS', 'P06', 'REV-2.00', 'BOM-YARIS-102', 60.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARIS-GAS', 'P07', 'REV-2.00', 'BOM-YARIS-102', 35.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARIS-GAS', 'P08', 'REV-2.00', 'BOM-YARIS-102', 55.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARIS-GAS', 'P09', 'REV-2.00', 'BOM-YARIS-102', 90.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARIS-GAS', 'P10', 'REV-2.00', 'BOM-YARIS-102', 45.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARIS-GAS', 'P11', 'REV-2.00', 'BOM-YARIS-102', 55.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARIS-GAS', 'P12', 'REV-2.00', 'BOM-YARIS-102', 25.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),

    -- BZ4X-EV (全12工程)
    ('BZ4X-EV', 'P01', 'REV-1.02', 'BOM-BZ4X-001', 30.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('BZ4X-EV', 'P02', 'REV-1.02', 'BOM-BZ4X-001', 45.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('BZ4X-EV', 'P03', 'REV-1.02', 'BOM-BZ4X-001', 90.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('BZ4X-EV', 'P04', 'REV-1.02', 'BOM-BZ4X-001', 120.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('BZ4X-EV', 'P05', 'REV-1.02', 'BOM-BZ4X-001', 60.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('BZ4X-EV', 'P06', 'REV-1.02', 'BOM-BZ4X-001', 80.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('BZ4X-EV', 'P07', 'REV-1.02', 'BOM-BZ4X-001', 50.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('BZ4X-EV', 'P08', 'REV-1.02', 'BOM-BZ4X-001', 70.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('BZ4X-EV', 'P09', 'REV-1.02', 'BOM-BZ4X-001', 100.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('BZ4X-EV', 'P10', 'REV-1.02', 'BOM-BZ4X-001', 55.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('BZ4X-EV', 'P11', 'REV-1.02', 'BOM-BZ4X-001', 65.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('BZ4X-EV', 'P12', 'REV-1.02', 'BOM-BZ4X-001', 35.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),

    -- RAV4-PHEV (全12工程)
    ('RAV4-PHEV', 'P01', 'REV-1.00', 'BOM-RAV4-004', 45.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('RAV4-PHEV', 'P02', 'REV-1.00', 'BOM-RAV4-004', 60.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('RAV4-PHEV', 'P03', 'REV-1.00', 'BOM-RAV4-004', 100.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('RAV4-PHEV', 'P04', 'REV-1.00', 'BOM-RAV4-004', 150.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('RAV4-PHEV', 'P05', 'REV-1.00', 'BOM-RAV4-004', 70.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('RAV4-PHEV', 'P06', 'REV-1.00', 'BOM-RAV4-004', 85.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('RAV4-PHEV', 'P07', 'REV-1.00', 'BOM-RAV4-004', 45.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('RAV4-PHEV', 'P08', 'REV-1.00', 'BOM-RAV4-004', 75.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('RAV4-PHEV', 'P09', 'REV-1.00', 'BOM-RAV4-004', 110.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('RAV4-PHEV', 'P10', 'REV-1.00', 'BOM-RAV4-004', 60.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('RAV4-PHEV', 'P11', 'REV-1.00', 'BOM-RAV4-004', 70.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('RAV4-PHEV', 'P12', 'REV-1.00', 'BOM-RAV4-004', 40.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),

    -- HIACE-DSL (全12工程)
    ('HIACE-DSL', 'P01', 'REV-1.05', 'BOM-HIACE-010', 40.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('HIACE-DSL', 'P02', 'REV-1.05', 'BOM-HIACE-010', 55.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('HIACE-DSL', 'P03', 'REV-1.05', 'BOM-HIACE-010', 95.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('HIACE-DSL', 'P04', 'REV-1.05', 'BOM-HIACE-010', 130.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('HIACE-DSL', 'P05', 'REV-1.05', 'BOM-HIACE-010', 65.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('HIACE-DSL', 'P06', 'REV-1.05', 'BOM-HIACE-010', 75.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('HIACE-DSL', 'P07', 'REV-1.05', 'BOM-HIACE-010', 30.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('HIACE-DSL', 'P08', 'REV-1.05', 'BOM-HIACE-010', 65.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('HIACE-DSL', 'P09', 'REV-1.05', 'BOM-HIACE-010', 105.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('HIACE-DSL', 'P10', 'REV-1.05', 'BOM-HIACE-010', 50.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('HIACE-DSL', 'P11', 'REV-1.05', 'BOM-HIACE-010', 65.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('HIACE-DSL', 'P12', 'REV-1.05', 'BOM-HIACE-010', 35.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),

    -- CROWN-HEV (全12工程)
    ('CROWN-HEV', 'P01', 'REV-1.00', 'BOM-CROWN-051', 38.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('CROWN-HEV', 'P02', 'REV-1.00', 'BOM-CROWN-051', 55.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('CROWN-HEV', 'P03', 'REV-1.00', 'BOM-CROWN-051', 90.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('CROWN-HEV', 'P04', 'REV-1.00', 'BOM-CROWN-051', 125.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('CROWN-HEV', 'P05', 'REV-1.00', 'BOM-CROWN-051', 60.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('CROWN-HEV', 'P06', 'REV-1.00', 'BOM-CROWN-051', 75.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('CROWN-HEV', 'P07', 'REV-1.00', 'BOM-CROWN-051', 40.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('CROWN-HEV', 'P08', 'REV-1.00', 'BOM-CROWN-051', 70.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('CROWN-HEV', 'P09', 'REV-1.00', 'BOM-CROWN-051', 100.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('CROWN-HEV', 'P10', 'REV-1.00', 'BOM-CROWN-051', 55.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('CROWN-HEV', 'P11', 'REV-1.00', 'BOM-CROWN-051', 65.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('CROWN-HEV', 'P12', 'REV-1.00', 'BOM-CROWN-051', 30.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),

    -- ALPH-HEV (全12工程)
    ('ALPH-HEV', 'P01', 'REV-3.01', 'BOM-ALPH-300', 45.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('ALPH-HEV', 'P02', 'REV-3.01', 'BOM-ALPH-300', 65.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('ALPH-HEV', 'P03', 'REV-3.01', 'BOM-ALPH-300', 110.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('ALPH-HEV', 'P04', 'REV-3.01', 'BOM-ALPH-300', 160.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('ALPH-HEV', 'P05', 'REV-3.01', 'BOM-ALPH-300', 75.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('ALPH-HEV', 'P06', 'REV-3.01', 'BOM-ALPH-300', 90.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('ALPH-HEV', 'P07', 'REV-3.01', 'BOM-ALPH-300', 50.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('ALPH-HEV', 'P08', 'REV-3.01', 'BOM-ALPH-300', 80.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('ALPH-HEV', 'P09', 'REV-3.01', 'BOM-ALPH-300', 120.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('ALPH-HEV', 'P10', 'REV-3.01', 'BOM-ALPH-300', 65.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('ALPH-HEV', 'P11', 'REV-3.01', 'BOM-ALPH-300', 75.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('ALPH-HEV', 'P12', 'REV-3.01', 'BOM-ALPH-300', 40.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),

    -- SIENTA-GAS (全12工程)
    ('SIENTA-GAS', 'P01', 'REV-2.00', 'BOM-SIENTA-201', 32.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('SIENTA-GAS', 'P02', 'REV-2.00', 'BOM-SIENTA-201', 48.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('SIENTA-GAS', 'P03', 'REV-2.00', 'BOM-SIENTA-201', 82.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('SIENTA-GAS', 'P04', 'REV-2.00', 'BOM-SIENTA-201', 108.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('SIENTA-GAS', 'P05', 'REV-2.00', 'BOM-SIENTA-201', 52.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('SIENTA-GAS', 'P06', 'REV-2.00', 'BOM-SIENTA-201', 62.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('SIENTA-GAS', 'P07', 'REV-2.00', 'BOM-SIENTA-201', 30.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('SIENTA-GAS', 'P08', 'REV-2.00', 'BOM-SIENTA-201', 58.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('SIENTA-GAS', 'P09', 'REV-2.00', 'BOM-SIENTA-201', 92.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('SIENTA-GAS', 'P10', 'REV-2.00', 'BOM-SIENTA-201', 46.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('SIENTA-GAS', 'P11', 'REV-2.00', 'BOM-SIENTA-201', 56.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('SIENTA-GAS', 'P12', 'REV-2.00', 'BOM-SIENTA-201', 26.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),

    -- COROLLA-G (全12工程)
    ('COROLLA-G', 'P01', 'REV-1.01', 'BOM-COROLLA-010', 33.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('COROLLA-G', 'P02', 'REV-1.01', 'BOM-COROLLA-010', 49.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('COROLLA-G', 'P03', 'REV-1.01', 'BOM-COROLLA-010', 83.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('COROLLA-G', 'P04', 'REV-1.01', 'BOM-COROLLA-010', 109.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('COROLLA-G', 'P05', 'REV-1.01', 'BOM-COROLLA-010', 53.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('COROLLA-G', 'P06', 'REV-1.01', 'BOM-COROLLA-010', 63.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('COROLLA-G', 'P07', 'REV-1.01', 'BOM-COROLLA-010', 31.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('COROLLA-G', 'P08', 'REV-1.01', 'BOM-COROLLA-010', 59.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('COROLLA-G', 'P09', 'REV-1.01', 'BOM-COROLLA-010', 93.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('COROLLA-G', 'P10', 'REV-1.01', 'BOM-COROLLA-010', 47.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('COROLLA-G', 'P11', 'REV-1.01', 'BOM-COROLLA-010', 57.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('COROLLA-G', 'P12', 'REV-1.01', 'BOM-COROLLA-010', 27.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),

    -- YARISC-HEV (全12工程)
    ('YARISC-HEV', 'P01', 'REV-1.00', 'BOM-YARISC-150', 34.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARISC-HEV', 'P02', 'REV-1.00', 'BOM-YARISC-150', 51.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARISC-HEV', 'P03', 'REV-1.00', 'BOM-YARISC-150', 86.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARISC-HEV', 'P04', 'REV-1.00', 'BOM-YARISC-150', 112.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARISC-HEV', 'P05', 'REV-1.00', 'BOM-YARISC-150', 54.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARISC-HEV', 'P06', 'REV-1.00', 'BOM-YARISC-150', 66.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARISC-HEV', 'P07', 'REV-1.00', 'BOM-YARISC-150', 38.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARISC-HEV', 'P08', 'REV-1.00', 'BOM-YARISC-150', 62.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARISC-HEV', 'P09', 'REV-1.00', 'BOM-YARISC-150', 96.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARISC-HEV', 'P10', 'REV-1.00', 'BOM-YARISC-150', 48.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARISC-HEV', 'P11', 'REV-1.00', 'BOM-YARISC-150', 58.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('YARISC-HEV', 'P12', 'REV-1.00', 'BOM-YARISC-150', 28.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),

    -- MIRAI-FCV (全12工程)
    ('MIRAI-FCV', 'P01', 'REV-1.00', 'BOM-MIRAI-701', 36.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('MIRAI-FCV', 'P02', 'REV-1.00', 'BOM-MIRAI-701', 54.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('MIRAI-FCV', 'P03', 'REV-1.00', 'BOM-MIRAI-701', 88.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('MIRAI-FCV', 'P04', 'REV-1.00', 'BOM-MIRAI-701', 115.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('MIRAI-FCV', 'P05', 'REV-1.00', 'BOM-MIRAI-701', 56.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('MIRAI-FCV', 'P06', 'REV-1.00', 'BOM-MIRAI-701', 72.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('MIRAI-FCV', 'P07', 'REV-1.00', 'BOM-MIRAI-701', 48.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('MIRAI-FCV', 'P08', 'REV-1.00', 'BOM-MIRAI-701', 68.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('MIRAI-FCV', 'P09', 'REV-1.00', 'BOM-MIRAI-701', 98.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('MIRAI-FCV', 'P10', 'REV-1.00', 'BOM-MIRAI-701', 52.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('MIRAI-FCV', 'P11', 'REV-1.00', 'BOM-MIRAI-701', 62.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('MIRAI-FCV', 'P12', 'REV-1.00', 'BOM-MIRAI-701', 32.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),

    -- GR86-GAS (全12工程)
    ('GR86-GAS', 'P01', 'REV-1.00', 'BOM-GR86-086', 31.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('GR86-GAS', 'P02', 'REV-1.00', 'BOM-GR86-086', 46.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('GR86-GAS', 'P03', 'REV-1.00', 'BOM-GR86-086', 81.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('GR86-GAS', 'P04', 'REV-1.00', 'BOM-GR86-086', 106.0, 's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('GR86-GAS', 'P05', 'REV-1.00', 'BOM-GR86-086', 51.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('GR86-GAS', 'P06', 'REV-1.00', 'BOM-GR86-086', 61.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('GR86-GAS', 'P07', 'REV-1.00', 'BOM-GR86-086', 30.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('GR86-GAS', 'P08', 'REV-1.00', 'BOM-GR86-086', 56.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('GR86-GAS', 'P09', 'REV-1.00', 'BOM-GR86-086', 91.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('GR86-GAS', 'P10', 'REV-1.00', 'BOM-GR86-086', 44.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('GR86-GAS', 'P11', 'REV-1.00', 'BOM-GR86-086', 54.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP()),
    ('GR86-GAS', 'P12', 'REV-1.00', 'BOM-GR86-086', 24.0,  's3://cf-engineering-bucket-dev/engineering_dev/raw/production_standard/cf_engineering_production_standard_20260612-102232.csv', CURRENT_TIMESTAMP());
