# %% [markdown]
# ### CSV RawデータをS3に格納する

# %%
from datetime import datetime
import zoneinfo

# ---------------------------------------------------------
# 1. 設定内容
# ---------------------------------------------------------
FACTORY_ID = "F01"

jst = zoneinfo.ZoneInfo("Asia/Tokyo")
current_time = datetime.now(jst).strftime("%Y%m%d-%H%M%S")
file_name = f"cf_mom_factory_raw_logs_{FACTORY_ID}_{current_time}.csv"
target_path = f"s3://cf-mom-factory-bucket-dev/mom_factory_dev/raw/{file_name}"

# ---------------------------------------------------------
# 2. CSVデータ
# ---------------------------------------------------------
csv_content = f"""log_id,vin,timestamp,factory_id,line_id,process_code,car_model_code,process_result_code,cycle_time_sec,defect_code,operator_id,parts_lot_no,recipe_id,4m_changed_flg,sequence_no
F01-L0001,VIN-F01-00001,2026/6/3 10:00,F01,LINE-B,P04,YARIS-GAS,1,101.7,NONE,OP-104,LOT-BAT-101,RCP-01,FALSE,1
F01-L0002,VIN-F01-00002,2026/6/3 10:43,F01,LINE-A,P01,BZ4X-EV,1,48.8,NONE,OP-101,LOT-STL-202,RCP-01,FALSE,2
F01-L0003,VIN-F01-00003,2026/6/3 10:12,F01,LINE-A,P02,BZ4X-EV,9,-1,DF-01,OP-201,LOT-STL-305,RCP-09,TRUE,3
F01-L0004,VIN-F01-00004,2026/6/3 11:09,F01,LINE-B,P04,BZ4X-EV,1,128.2,NONE,OP-102,LOT-BAT-102,RCP-02,FALSE,4
F01-L0005,VIN-F01-00005,2026/6/3 12:20,F01,LINE-A,P05,YARIS-GAS,1,44.3,NONE,OP-102,LOT-NONE,RCP-01,FALSE,5
F01-L0006,VIN-F01-00006,2026/6/3 10:40,F01,LINE-B,P05,YARIS-GAS,9,57.1,DF-03,OP-201,LOT-NONE,RCP-01,TRUE,6
F01-L0007,VIN-F01-00007,2026/6/3 12:12,F01,LINE-B,P04,BZ4X-EV,1,128.7,NONE,OP-202,LOT-BAT-105,RCP-01,FALSE,7
F01-L0008,VIN-F01-00008,2026/6/3 12:48,F01,LINE-B,P05,BZ4X-EV,1,107.6,NONE,OP-205,LOT-NONE,RCP-01,FALSE,8
F01-L0009,VIN-F01-00009,2026/6/3 12:24,F01,LINE-A,P01,YARIS-GAS,1,123.8,NONE,OP-104,LOT-STL-202,RCP-01,FALSE,9
F01-L0010,VIN-F01-00010,2026/6/3 10:45,F01,LINE-A,P01,YARIS-GAS,1,39.5,NONE,OP-101,LOT-STL-202,RCP-01,FALSE,10
F01-L0011,VIN-F01-00011,2026/6/3 11:40,F01,LINE-A,P01,BZ4X-EV,1,114.9,NONE,OP-205,LOT-STL-205,RCP-01,FALSE,11
F01-L0012,VIN-F01-00012,2026/6/3 16:47,F01,LINE-A,P01,BZ4X-EV,1,NONE,NONE,OP-205,LOT-STL-205,RCP-01,FALSE,12
F01-L0013,VIN-F01-00013,2026/6/3 16:36,F01,LINE-B,P04,BZ4X-EV,1,72.6,NONE,OP-205,LOT-BAT-102,RCP-02,FALSE,13
F01-L0014,VIN-F01-00014,2026/6/3 17:35,F01,LINE-B,P03,YARIS-GAS,1,37.9,NONE,OP-205,LOT-PNT-001,RCP-01,FALSE,14
F01-L0015,VIN-F01-00015,2026/6/3 13:30,F01,LINE-A,P01,BZ4X-EV,1,32.2,NONE,OP-205,LOT-STL-305,RCP-09,FALSE,15
"""

# ---------------------------------------------------------
# 3. ファイル書き込み実行
# ---------------------------------------------------------
try:
    dbutils.fs.put(target_path, csv_content.strip(), overwrite=True)
    print(f"SUCCESS: {target_path}")

except Exception as e:
    print(f"ERROR: {str(e)}")

# %%
from datetime import datetime
import zoneinfo

# ---------------------------------------------------------
# 1. 設定内容
# ---------------------------------------------------------
FACTORY_ID = "F01"

jst = zoneinfo.ZoneInfo("Asia/Tokyo")
current_time = datetime.now(jst).strftime("%Y%m%d-%H%M%S")
file_name = f"cf_mom_factory_raw_logs_{FACTORY_ID}_{current_time}.csv"
target_path = f"s3://cf-mom-factory-bucket-dev/mom_factory_dev/raw/{file_name}"

# ---------------------------------------------------------
# 2. CSVデータ
# ---------------------------------------------------------
csv_content = f"""log_id,vin,timestamp,factory_id,line_id,process_code,car_model_code,process_result_code,cycle_time_sec,defect_code,operator_id,parts_lot_no,recipe_id,4m_changed_flg,sequence_no
F01-L0016,VIN-F01-00016,2026/6/4 14:05,F01,LINE-B,P04,YARIS-GAS,1,105.3,NONE,OP-104,LOT-BAT-101,RCP-01,FALSE,16
F01-L0017,VIN-F01-00017,2026/6/4 14:22,F01,LINE-A,P02,YARIS-GAS,1,58.4,NONE,OP-101,LOT-STL-202,RCP-01,FALSE,17
F01-L0018,VIN-F01-00018,2026/6/4 14:50,F01,LINE-B,P03,BZ4X-EV,1,89.1,NONE,OP-202,LOT-PNT-002,RCP-02,FALSE,18
F01-L0019,VIN-F01-00019,2026/6/4 15:10,F01,LINE-A,P04,YARIS-GAS,9,142,DF-02,OP-102,LOT-BAT-105,RCP-01,FALSE,19
F01-L0019,VIN-F01-00019,2026/6/4 15:10,F01,LINE-A,P04,YARIS-GAS,9,142,DF-02,OP-102,LOT-BAT-105,RCP-01,TRUE,20
F01-L0020,VIN-F01-00010,2026/6/4 15:35,F01,LINE-B,P01,YARIS-GAS,1,41.2,NONE,OP-104,LOT-STL-202,RCP-01,FALSE,21
F01-L0021,VIN-F01-00021,2026/6/4 15:58,F01,LINE-A,P05,BZ4X-EV,1,112.5,NONE,OP-205,LOT-NONE,RCP-09,FALSE,22
F01-L0022,VIN-F01-00022,2026/6/4 16:15,F01,LINE-B,P02,YARIS-GAS,9,-1,DF-01,OP-201,LOT-STL-202,RCP-01,FALSE,23
F01-L0023,VIN-F01-00023,2026/6/4 16:40,F01,LINE-A,P03,YARIS-GAS,1,75.3,NONE,OP-101,LOT-PNT-001,RCP-01,FALSE,24
F01-L0024,VIN-F01-00024,2026/6/4 17:02,F01,LINE-B,P04,YARIS-GAS,1,NONE,NONE,OP-202,LOT-BAT-101,RCP-01,FALSE,25
F01-L0025,VIN-F01-00025,2026/6/4 17:25,F01,LINE-A,P05,YARIS-GAS,1,43.9,NONE,OP-102,LOT-NONE,RCP-01,FALSE,26
F01-L0026,VIN-F01-00026,2026/6/4 17:50,F01,LINE-B,P01,BZ4X-EV,1,35.8,NONE,OP-104,LOT-STL-305,RCP-09,FALSE,27
F01-L0027,VIN-F01-00027,2026/6/4 18:15,F01,LINE-A,P04,BZ4X-EV,1,131.4,NONE,OP-205,LOT-BAT-102,RCP-02,TRUE,28
F01-L0028,VIN-F01-00028,2026/6/4 18:38,F01,LINE-A,P02,YARIS-GAS,1,49.2,NONE,OP-101,LOT-STL-202,RCP-01,FALSE,29
F01-L0029,VIN-F01-00029,2026/6/4 19:00,F01,LINE-B,P03,YARIS-GAS,1,71.5,NONE,OP-202,LOT-PNT-001,RCP-01,FALSE,30
F01-L0030,VIN-F01-00030,2026/6/4 19:25,F01,LINE-B,P05,BZ4X-EV,9,62,DF-03,OP-201,LOT-NONE,RCP-09,FALSE,31
"""

# ---------------------------------------------------------
# 3. ファイル書き込み実行
# ---------------------------------------------------------
try:
    dbutils.fs.put(target_path, csv_content.strip(), overwrite=True)
    print(f"SUCCESS: {target_path}")

except Exception as e:
    print(f"ERROR: {str(e)}")

# %%
from datetime import datetime
import zoneinfo

# ---------------------------------------------------------
# 1. 設定内容
# ---------------------------------------------------------
FACTORY_ID = "F02"

jst = zoneinfo.ZoneInfo("Asia/Tokyo")
current_time = datetime.now(jst).strftime("%Y%m%d-%H%M%S")
file_name = f"cf_mom_factory_raw_logs_{FACTORY_ID}_{current_time}.csv"
target_path = f"s3://cf-mom-factory-bucket-dev/mom_factory_dev/raw/{file_name}"

# ---------------------------------------------------------
# 2. CSVデータ
# ---------------------------------------------------------
csv_content = f"""log_id,vin,timestamp,factory_id,line_id,process_code,car_model_code,process_result_code,cycle_time_sec,defect_code,operator_id,parts_lot_no,recipe_id,4m_changed_flg,sequence_no
F02-L0001,VIN-F02-00001,2026/6/15 08:15,F02,LINE-1,P06,PRIUS-HEV,1,72.4,NONE,OP-103,LOT-ENG-101,RCP-06,FALSE,1
F02-L0002,VIN-F02-00002,2026/6/15 08:40,F02,LINE-2,P01,ALPH-HEV,1,44.1,NONE,OP-203,LOT-STL-501,RCP-01,FALSE,2
F02-L0003,VIN-F02-00003,2026/6/15 09:10,F02,LINE-1,P07,PRIUS-HEV,1,39.8,NONE,OP-206,LOT-BAT-201,RCP-07,FALSE,3
F02-L0004,VIN-F02-00004,2026/6/15 09:35,F02,LINE-2,P04,ALPH-HEV,9,-1,DF-02,OP-105,LOT-HVY-001,RCP-04,TRUE,4
F02-L0005,VIN-F02-00005,2026/6/15 10:05,F02,LINE-1,P08,RAV4-PHEV,1,76.2,NONE,OP-207,LOT-CHA-301,RCP-08,FALSE,5
F02-L0022,VIN-F02-00022,2026/6/16 11:05,F02,LINE-1,P06,RAV4-PHEV,1,84.5,NONE,OP-103,LOT-ENG-105,RCP-06,FALSE,23
F02-L0023,VIN-F02-00023,2026/6/16 11:30,F02,LINE-2,P01,PRIUS-HEV,1,34.9,NONE,OP-203,LOT-STL-504,RCP-01,FALSE,24
F02-L0024,VIN-F02-00024,2026/6/16 13:00,F02,LINE-1,P07,RAV4-PHEV,1,44.8,NONE,OP-206,LOT-BAT-204,RCP-07,FALSE,25
F02-L0025,VIN-F02-00025,2026/6/16 13:25,F02,LINE-2,P04,ALPH-HEV,1,162.1,NONE,OP-105,LOT-HVY-004,RCP-04,FALSE,26
F02-L0026,VIN-F02-00026,2026/6/16 13:50,F02,LINE-1,P08,PRIUS-HEV,1,63.8,NONE,OP-207,LOT-CHA-304,RCP-08,FALSE,27
F02-L0027,VIN-F02-00027,2026/6/16 14:15,F02,LINE-2,P11,PRIUS-HEV,1,29.5,NONE,OP-107,LOT-NONE,RCP-11,FALSE,28
F02-L0028,VIN-F02-00028,2026/6/16 14:40,F02,LINE-1,P06,ALPH-HEV,1,89.7,NONE,OP-204,LOT-ENG-106,RCP-06,FALSE,29
F02-L0029,VIN-F02-00029,2026/6/16 15:05,F02,LINE-2,P02,RAV4-PHEV,1,61.2,NONE,OP-202,LOT-WLD-002,RCP-02,FALSE,30
F02-L0030,VIN-F02-00030,2026/6/16 15:35,F02,LINE-1,P11,RAV4-PHEV,9,60.0,DF-03,OP-201,LOT-NONE,RCP-11,FALSE,31
"""

# ---------------------------------------------------------
# 3. ファイル書き込み実行
# ---------------------------------------------------------
try:
    dbutils.fs.put(target_path, csv_content.strip(), overwrite=True)
    print(f"SUCCESS: {target_path}")

except Exception as e:
    print(f"ERROR: {str(e)}")

# %%
from datetime import datetime
import zoneinfo

# ---------------------------------------------------------
# 1. 設定内容
# ---------------------------------------------------------
FACTORY_ID = "F02"

jst = zoneinfo.ZoneInfo("Asia/Tokyo")
current_time = datetime.now(jst).strftime("%Y%m%d-%H%M%S")
file_name = f"cf_mom_factory_raw_logs_{FACTORY_ID}_{current_time}.csv"
target_path = f"s3://cf-mom-factory-bucket-dev/mom_factory_dev/raw/{file_name}"

# ---------------------------------------------------------
# 2. CSVデータ
# ---------------------------------------------------------
csv_content = f"""log_id,vin,timestamp,factory_id,line_id,process_code,car_model_code,process_result_code,cycle_time_sec,defect_code,operator_id,parts_lot_no,recipe_id,4m_changed_flg,sequence_no
F02-L0019,VIN-F02-00019,2026/6/16 09:40,F02,LINE-2,P04,ALPH-HEV,1,120.5,NONE,OP-105,LOT-HVY-003,RCP-04,FALSE,32
"""

# ---------------------------------------------------------
# 3. ファイル書き込み実行
# ---------------------------------------------------------
try:
    dbutils.fs.put(target_path, csv_content.strip(), overwrite=True)
    print(f"SUCCESS: {target_path}")

except Exception as e:
    print(f"ERROR: {str(e)}")
